# %% [markdown]
# ## Load packages

# %%
# Define IAM role
import boto3
import re
from sagemaker import get_execution_role
from sagemaker.session import Session
from sagemaker.feature_store.feature_group import FeatureGroup
import yaml
import numpy as np                                # For matrix operations and numerical processing
import pandas as pd                               # For munging tabular data
import matplotlib.pyplot as plt                   # For charts and visualizations
from IPython.display import Image                 # For displaying images in the notebook
from IPython.display import display               # For displaying outputs in the notebook
from time import gmtime, strftime                 # For labeling SageMaker models, endpoints, etc.
import sys                                        # For writing outputs to notebook
import math                                       # For ceiling function
import json                                       # For parsing hosting outputs
import os                                         # For manipulating filepath names
import sagemaker 
import zipfile     # Amazon SageMaker's Python SDK provides many helper functions
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Load Configs

# %%
role = get_execution_role()
region = boto3.Session().region_name

feature_group_name = "taxi-feature-group-no-encoding"
bucket = sagemaker.Session().default_bucket()
prefix = "sagemaker/xgboost_model"

# %%
bucket
# Out:
# 'sagemaker-ap-southeast-2-949757562939'

# %% [markdown]
# ## Get data from Feature Store

# %%
# Connect to the Feature Store
boto_session = boto3.Session(region_name=region)

sagemaker_client = boto_session.client(service_name='sagemaker', region_name=region)
featurestore_runtime = boto_session.client(service_name='sagemaker-featurestore-runtime', region_name=region)

feature_store_session = Session(
    boto_session=boto_session,
    sagemaker_client=sagemaker_client,
    sagemaker_featurestore_runtime_client=featurestore_runtime
)

feature_group = FeatureGroup(name=feature_group_name, sagemaker_session=feature_store_session)

# %%
# Build SQL query to features group
fs_query = feature_group.athena_query()
fs_table = fs_query.table_name
query_string = 'SELECT * FROM "'+fs_table+'"'
print('Running ' + query_string)
# Out:
# Running SELECT * FROM "taxi_feature_group_no_encoding_1693400933"

# %%
# Run Athena query. The output is loaded to a Pandas dataframe.
fs_query.run(query_string=query_string, output_location='s3://'+bucket+'/'+prefix+'/fs_query_results/')
fs_query.wait()
model_data = fs_query.as_dataframe()

# %%
model_data = model_data.drop(['fs_id', 'fs_time', 'write_time', 'api_invocation_time', 'is_deleted'], axis=1)

# %%
model_data.head()
# Out:
#    trip_seconds  trip_miles  pickup_community_area  dropoff_community_area  \
# 0        1513.0       14.65                     56                       8
# 1        1260.0       16.30                     76                       8
# 2        1082.0        9.39                     33                      77
# 3        1144.0       11.97                      8                      40
# 4         731.0        4.33                     32                       6
#
#    tips  tolls  extras  trip_total payment_type  pickup_centroid_latitude  \
# 0   2.0      0       5       45.00  credit_card                 41.792592
# 1   9.0      0       4       53.75  credit_card                 41.980264
# 2   0.0      0       0       25.25       prcard                 41.857184
# 3   0.0      0       0       31.00       prcard                 41.899602
# 4   0.0      0       0       14.25         cash                 41.878866
#
#    pickup_centroid_longitude  dropoff_centroid_latitude  \
# 0                 -87.769615                  41.899602
# 1                 -87.913625                  41.899602
# 2                 -87.620335                  41.986712
# 3                 -87.633308                  41.792357
# 4                 -87.625192                  41.944227
#
#    dropoff_centroid_longitude  start_month  start_day  start_hour  \
# 0                  -87.633308            1         30          23
# 1                  -87.633308            1         30          23
# 2                  -87.663416            1         30          23
# 3                  -87.617931            1         30          23
# 4                  -87.655998            1         30          23
#
#    start_minute
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
model_data.shape
# Out:
# (174724, 17)

# %%
model_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174724 entries, 0 to 174723
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   trip_seconds                174695 non-null  float64
#  1   trip_miles                  174724 non-null  float64
#  2   pickup_community_area       174724 non-null  int64
#  3   dropoff_community_area      174724 non-null  int64
#  4   tips                        174724 non-null  float64
#  5   tolls                       174724 non-null  int64
#  6   extras                      174724 non-null  int64
#  7   trip_total                  174724 non-null  float64
#  8   payment_type                174724 non-null  object
#  9   pickup_centroid_latitude    174724 non-null  float64
#  10  pickup_centroid_longitude   174724 non-null  float64
#  11  dropoff_centroid_latitude   174724 non-null  float64
#  12  dropoff_centroid_longitude  174724 non-null  float64
#  13  start_month                 174724 non-null  int64
#  14  start_day                   174724 non-null  int64
#  15  start_hour                  174724 non-null  int64
#  16  start_minute                174724 non-null  int64
# dtypes: float64(8), int64(8), object(1)
# memory usage: 22.7+ MB

# %% [markdown]
# ## Create dummies

# %%
model_data_dum = pd.get_dummies(model_data)

# %%
model_data_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174724 entries, 0 to 174723
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   trip_seconds                174695 non-null  float64
#  1   trip_miles                  174724 non-null  float64
#  2   pickup_community_area       174724 non-null  int64
#  3   dropoff_community_area      174724 non-null  int64
#  4   tips                        174724 non-null  float64
#  5   tolls                       174724 non-null  int64
#  6   extras                      174724 non-null  int64
#  7   trip_total                  174724 non-null  float64
#  8   pickup_centroid_latitude    174724 non-null  float64
#  9   pickup_centroid_longitude   174724 non-null  float64
#  10  dropoff_centroid_latitude   174724 non-null  float64
#  11  dropoff_centroid_longitude  174724 non-null  float64
#  12  start_month                 174724 non-null  int64
#  13  start_day                   174724 non-null  int64
#  14  start_hour                  174724 non-null  int64
#  15  start_minute                174724 non-null  int64
#  16  payment_type_cash           174724 non-null  uint8
#  17  payment_type_credit_card    174724 non-null  uint8
#  18  payment_type_dispute        174724 non-null  uint8
#  19  payment_type_mobile         174724 non-null  uint8
#  20  payment_type_no_charge      174724 non-null  uint8
#  21  payment_type_prcard         174724 non-null  uint8
#  22  payment_type_unknown        174724 non-null  uint8
# dtypes: float64(8), int64(8), uint8(7)
# memory usage: 22.5 MB

# %%
pd.set_option('display.max_columns', None)
model_data_dum.head()
# Out:
#    trip_seconds  trip_miles  pickup_community_area  dropoff_community_area  \
# 0        1513.0       14.65                     56                       8
# 1        1260.0       16.30                     76                       8
# 2        1082.0        9.39                     33                      77
# 3        1144.0       11.97                      8                      40
# 4         731.0        4.33                     32                       6
#
#    tips  tolls  extras  trip_total  pickup_centroid_latitude  \
# 0   2.0      0       5       45.00                 41.792592
# 1   9.0      0       4       53.75                 41.980264
# 2   0.0      0       0       25.25                 41.857184
# 3   0.0      0       0       31.00                 41.899602
# 4   0.0      0       0       14.25                 41.878866
#
#    pickup_centroid_longitude  dropoff_centroid_latitude  \
# 0                 -87.769615                  41.899602
# 1                 -87.913625                  41.899602
# 2                 -87.620335                  41.986712
# 3                 -87.633308                  41.792357
# 4                 -87.625192                  41.944227
#
#    dropoff_centroid_longitude  start_month  start_day  start_hour  \
# 0                  -87.633308            1         30          23
# 1                  -87.633308            1         30          23
# 2                  -87.663416            1         30          23
# 3                  -87.617931            1         30          23
# 4                  -87.655998            1         30          23
#
#    start_minute  payment_type_cash  payment_type_credit_card  \
# 0             0                  0                         1
# 1             0                  0                         1
# 2             0                  0                         0
# 3             0                  0                         0
# 4             0                  1                         0
#
#    payment_type_dispute  payment_type_mobile  payment_type_no_charge  \
# 0                     0                    0                       0
# 1                     0                    0                       0
# 2                     0                    0                       0
# 3                     0                    0                       0
# 4                     0                    0                       0
#
#    payment_type_prcard  payment_type_unknown
# 0                    0                     0
# 1                    0                     0
# 2                    1                     0
# 3                    1                     0
# 4                    0                     0

# %% [markdown]
# ## Prepare Dataset for Training, Test, and Validation

# %%
# Randomly sort the data then split out first 70%, second 20%, and last 10%
# train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data)), int(0.9 * len(model_data))])
train_data, validation_data, test_data = np.split(model_data_dum.sample(frac=1, random_state=1729), [int(0.7 * len(model_data_dum)), int(0.9 * len(model_data_dum))])

# %%
# Move the target variable to the first column
pd.concat([train_data['trip_total'], train_data.drop(['trip_total'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False)
pd.concat([validation_data['trip_total'], validation_data.drop(['trip_total'], axis=1)], axis=1).to_csv('validation.csv', index=False, header=False)

# %%
# Upload the training and validation dataset into S3 bucket.
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')

# %% [markdown]
# ## Training

# %%
# Select the xgboost built in container
container = sagemaker.image_uris.retrieve(region=region, framework='xgboost', version='1.7-1')

# Get the input and validation path
s3_input_train = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

sess = sagemaker.Session()

hyperparameters = {
        "max_depth":"5",
        "eta":"0.2",
        "gamma":"4",
        "min_child_weight":"6",
        "subsample":"0.7",
        "objective":"reg:squarederror",
        "num_round":"500"}

xgb = sagemaker.estimator.Estimator(container,
                                    role, 
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess,
                                    hyperparameters=hyperparameters
                                   )

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-08-31-04-17-30-930
# 2023-08-31 04:17:31 Starting - Starting the training job......
# 2023-08-31 04:18:06 Starting - Preparing the instances for training......
# 2023-08-31 04:19:14 Downloading - Downloading input data...
# 2023-08-31 04:19:39 Training - Downloading the training image...
# 2023-08-31 04:20:25 Training - Training image download completed. Training in progress....[2023-08-31 04:20:41.831 ip-10-0-243-181.ap-southeast-2.compute.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-08-31 04:20:41.859 ip-10-0-243-181.ap-southeast-2.compute.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-08-31:04:20:42:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-08-31:04:20:42:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-08-31:04:20:42:INFO] No GPUs detected (normal if no gpus installed)
# [2023-08-31:04:20:42:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-08-31:04:20:42:INFO] Determined 0 GPU(s) available on the instance.
# [2023-08-31:04:20:42:INFO] Determined delimiter of CSV input is ','
# [2023-08-31:04:20:42:INFO] Determined delimiter of CSV input is ','
# [2023-08-31:04:20:42:INFO] files path: /opt/ml/input/data/train
# [2023-08-31:04:20:42:INFO] Determined delimiter of CSV input is ','
# [2023-08-31:04:20:42:INFO] files path: /opt/ml/input/data/validation
# [2023-08-31:04:20:42:INFO] Determined delimiter of CSV input is ','
# [2023-08-31:04:20:42:INFO] Single node training.
# [2023-08-31:04:20:42:INFO] Train matrix has 122306 rows and 22 columns
# [2023-08-31:04:20:42:INFO] Validation matrix has 34945 rows
# [2023-08-31 04:20:42.539 ip-10-0-243-181.ap-southeast-2.compute.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-08-31 04:20:42.540 ip-10-0-243-181.ap-southeast-2.compute.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-08-31 04:20:42.541 ip-10-0-243-181.ap-southeast-2.compute.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-08-31 04:20:42.541 ip-10-0-243-181.ap-southeast-2.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-08-31:04:20:42:INFO] Debug hook created from config
# [0]#011train-rmse:34.58570#011validation-rmse:26.34957
# [2023-08-31 04:20:42.814 ip-10-0-243-181.ap-southeast-2.compute.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-08-31 04:20:42.817 ip-10-0-243-181.ap-southeast-2.compute.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [1]#011train-rmse:31.00033#011validation-rmse:21.51838
# [2]#011train-rmse:28.41435#011validation-rmse:17.71452
# [3]#011train-rmse:26.55998#011validation-rmse:14.78825
# [4]#011train-rmse:25.27926#011validation-rmse:12.51005
# [5]#011train-rmse:24.43620#011validation-rmse:10.75782
# [6]#011train-rmse:23.87085#011validation-rmse:9.45161
# [7]#011train-rmse:23.45311#011validation-rmse:8.50678
# [8]#011train-rmse:23.17513#011validation-rmse:7.83172
# [9]#011train-rmse:22.99559#011validation-rmse:7.36800
# [10]#011train-rmse:22.87912#011validation-rmse:7.03806
# [11]#011train-rmse:22.81516#011validation-rmse:6.79976
# [12]#011train-rmse:22.74363#011validation-rmse:6.62387
# [13]#011train-rmse:22.69519#011validation-rmse:6.55123
# [14]#011train-rmse:22.66548#011validation-rmse:6.46718
# [15]#011train-rmse:22.63975#011validation-rmse:6.39882
# [16]#011train-rmse:22.61549#011validation-rmse:6.34862
# [17]#011train-rmse:22.53525#011validation-rmse:6.34738
# [18]#011train-rmse:22.51087#011validation-rmse:6.30942
# [19]#011train-rmse:22.50385#011validation-rmse:6.28434
# [20]#011train-rmse:22.49594#011validation-rmse:6.26612
# [21]#011train-rmse:22.48142#011validation-rmse:6.26171
# [22]#011train-rmse:22.48196#011validation-rmse:6.25199
# [23]#011train-rmse:22.47873#011validation-rmse:6.25642
# [24]#011train-rmse:22.46499#011validation-rmse:6.25095
# [25]#011train-rmse:22.46709#011validation-rmse:6.26180
# [26]#011train-rmse:22.45697#011validation-rmse:6.25533
# [27]#011train-rmse:22.45141#011validation-rmse:6.24109
# [28]#011train-rmse:22.33811#011validation-rmse:6.31070
# [29]#011train-rmse:22.33449#011validation-rmse:6.29958
# [30]#011train-rmse:22.33408#011validation-rmse:6.29009
# [31]#011train-rmse:22.33109#011validation-rmse:6.28647
# [32]#011train-rmse:22.31940#011validation-rmse:6.29534
# [33]#011train-rmse:22.31241#011validation-rmse:6.28678
# [34]#011train-rmse:22.30048#011validation-rmse:6.29126
# [35]#011train-rmse:22.30121#011validation-rmse:6.28420
# [36]#011train-rmse:22.20331#011validation-rmse:6.47931
# [37]#011train-rmse:22.20957#011validation-rmse:6.47077
# [38]#011train-rmse:22.18775#011validation-rmse:6.49686
# [39]#011train-rmse:22.11467#011validation-rmse:6.74517
# [40]#011train-rmse:22.08943#011validation-rmse:6.73354
# [41]#011train-rmse:21.98870#011validation-rmse:6.78051
# [42]#011train-rmse:21.98572#011validation-rmse:6.77510
# [43]#011train-rmse:21.98555#011validation-rmse:6.76664
# [44]#011train-rmse:21.98040#011validation-rmse:6.77219
# [45]#011train-rmse:21.98314#011validation-rmse:6.79256
# [46]#011train-rmse:21.97775#011validation-rmse:6.80848
# [47]#011train-rmse:21.97307#011validation-rmse:6.81736
# [48]#011train-rmse:21.95125#011validation-rmse:6.81167
# [49]#011train-rmse:21.95271#011validation-rmse:6.82035
# [50]#011train-rmse:21.95869#011validation-rmse:6.78507
# [51]#011train-rmse:21.97608#011validation-rmse:6.77355
# [52]#011train-rmse:21.94189#011validation-rmse:6.77639
# [53]#011train-rmse:21.93037#011validation-rmse:6.76975
# [54]#011train-rmse:21.93929#011validation-rmse:6.69847
# [55]#011train-rmse:21.93979#011validation-rmse:6.69969
# [56]#011train-rmse:21.85035#011validation-rmse:6.85758
# [57]#011train-rmse:21.83587#011validation-rmse:6.87305
# [58]#011train-rmse:21.83148#011validation-rmse:6.87871
# [59]#011train-rmse:21.83341#011validation-rmse:6.87735
# [60]#011train-rmse:21.83161#011validation-rmse:6.87452
# [61]#011train-rmse:21.82768#011validation-rmse:6.86681
# [62]#011train-rmse:21.82899#011validation-rmse:6.86088
# [63]#011train-rmse:21.85625#011validation-rmse:6.68937
# [64]#011train-rmse:21.85553#011validation-rmse:6.68852
# [65]#011train-rmse:21.90171#011validation-rmse:6.56939
# [66]#011train-rmse:21.82785#011validation-rmse:6.78434
# [67]#011train-rmse:21.83202#011validation-rmse:6.74026
# [68]#011train-rmse:21.82429#011validation-rmse:6.74108
# [69]#011train-rmse:21.82285#011validation-rmse:6.72733
# [70]#011train-rmse:21.74369#011validation-rmse:6.81791
# [71]#011train-rmse:21.74506#011validation-rmse:6.81774
# [72]#011train-rmse:21.74437#011validation-rmse:6.81962
# [73]#011train-rmse:21.73713#011validation-rmse:6.83050
# [74]#011train-rmse:21.73961#011validation-rmse:6.83401
# [75]#011train-rmse:21.73123#011validation-rmse:6.85813
# [76]#011train-rmse:21.75365#011validation-rmse:6.69286
# [77]#011train-rmse:21.75418#011validation-rmse:6.68631
# [78]#011train-rmse:21.68797#011validation-rmse:6.65493
# [79]#011train-rmse:21.70031#011validation-rmse:6.60684
# [80]#011train-rmse:21.75460#011validation-rmse:6.52952
# [81]#011train-rmse:21.66250#011validation-rmse:6.76626
# [82]#011train-rmse:21.62120#011validation-rmse:6.93133
# [83]#011train-rmse:21.57468#011validation-rmse:6.99382
# [84]#011train-rmse:21.56876#011validation-rmse:6.99578
# [85]#011train-rmse:21.43939#011validation-rmse:7.21421
# [86]#011train-rmse:21.43292#011validation-rmse:7.21887
# [87]#011train-rmse:21.42886#011validation-rmse:7.22273
# [88]#011train-rmse:21.43270#011validation-rmse:7.22607
# [89]#011train-rmse:21.43834#011validation-rmse:7.22353
# [90]#011train-rmse:21.46880#011validation-rmse:7.05839
# [91]#011train-rmse:21.49632#011validation-rmse:6.93611
# [92]#011train-rmse:21.48160#011validation-rmse:7.00540
# [93]#011train-rmse:21.39933#011validation-rmse:7.22103
# [94]#011train-rmse:21.40880#011validation-rmse:7.21998
# [95]#011train-rmse:21.40566#011validation-rmse:7.14451
# [96]#011train-rmse:21.41067#011validation-rmse:7.14368
# [97]#011train-rmse:21.42656#011validation-rmse:6.98283
# [98]#011train-rmse:21.43676#011validation-rmse:6.93636
# [99]#011train-rmse:21.43117#011validation-rmse:6.91448
# [100]#011train-rmse:21.39265#011validation-rmse:7.20033
# [101]#011train-rmse:21.28742#011validation-rmse:7.32419
# [102]#011train-rmse:21.28414#011validation-rmse:7.32380
# [103]#011train-rmse:21.31699#011validation-rmse:7.15072
# [104]#011train-rmse:21.31080#011validation-rmse:7.15949
# [105]#011train-rmse:21.26193#011validation-rmse:7.54930
# [106]#011train-rmse:21.25966#011validation-rmse:7.53713
# [107]#011train-rmse:21.25620#011validation-rmse:7.53604
# [108]#011train-rmse:21.25961#011validation-rmse:7.53789
# [109]#011train-rmse:21.23408#011validation-rmse:7.78870
# [110]#011train-rmse:21.24574#011validation-rmse:7.52645
# [111]#011train-rmse:21.25102#011validation-rmse:7.52219
# [112]#011train-rmse:21.27342#011validation-rmse:7.32649
# [113]#011train-rmse:21.27019#011validation-rmse:7.31257
# [114]#011train-rmse:21.20247#011validation-rmse:7.57757
# [115]#011train-rmse:21.24187#011validation-rmse:7.40757
# [116]#011train-rmse:21.23664#011validation-rmse:7.42279
# [117]#011train-rmse:21.15577#011validation-rmse:7.42301
# [118]#011train-rmse:21.15182#011validation-rmse:7.43184
# [119]#011train-rmse:21.14770#011validation-rmse:7.44135
# [120]#011train-rmse:21.14500#011validation-rmse:7.43854
# [121]#011train-rmse:21.14450#011validation-rmse:7.39061
# [122]#011train-rmse:21.15285#011validation-rmse:7.34545
# [123]#011train-rmse:21.14255#011validation-rmse:7.40601
# [124]#011train-rmse:21.14065#011validation-rmse:7.41030
# [125]#011train-rmse:21.14344#011validation-rmse:7.41715
# [126]#011train-rmse:21.14142#011validation-rmse:7.46482
# [127]#011train-rmse:21.16293#011validation-rmse:7.35278
# [128]#011train-rmse:21.16707#011validation-rmse:7.35783
# [129]#011train-rmse:21.18652#011validation-rmse:7.27610
# [130]#011train-rmse:21.19083#011validation-rmse:7.28144
# [131]#011train-rmse:21.19635#011validation-rmse:7.34740
# [132]#011train-rmse:21.19346#011validation-rmse:7.35286
# [133]#011train-rmse:21.16467#011validation-rmse:7.41826
# [134]#011train-rmse:20.86878#011validation-rmse:7.67700
# [135]#011train-rmse:20.86647#011validation-rmse:7.50274
# [136]#011train-rmse:20.85805#011validation-rmse:7.52188
# [137]#011train-rmse:20.85807#011validation-rmse:7.52764
# [138]#011train-rmse:20.84098#011validation-rmse:7.57733
# [139]#011train-rmse:20.85081#011validation-rmse:7.58231
# [140]#011train-rmse:20.84753#011validation-rmse:7.44773
# [141]#011train-rmse:20.90818#011validation-rmse:7.36337
# [142]#011train-rmse:20.78153#011validation-rmse:7.52479
# [143]#011train-rmse:20.82932#011validation-rmse:7.40645
# [144]#011train-rmse:20.76963#011validation-rmse:7.55724
# [145]#011train-rmse:20.76095#011validation-rmse:7.55612
# [146]#011train-rmse:20.75277#011validation-rmse:7.55762
# [147]#011train-rmse:20.74364#011validation-rmse:7.60947
# [148]#011train-rmse:20.78077#011validation-rmse:7.45044
# [149]#011train-rmse:20.82168#011validation-rmse:7.30613
# [150]#011train-rmse:20.77658#011validation-rmse:7.50661
# [151]#011train-rmse:20.77019#011validation-rmse:7.55497
# [152]#011train-rmse:20.76836#011validation-rmse:7.55127
# [153]#011train-rmse:20.76530#011validation-rmse:7.57104
# [154]#011train-rmse:20.79033#011validation-rmse:7.43756
# [155]#011train-rmse:20.75103#011validation-rmse:7.56861
# [156]#011train-rmse:20.78897#011validation-rmse:7.42457
# [157]#011train-rmse:20.73572#011validation-rmse:7.61241
# [158]#011train-rmse:20.74271#011validation-rmse:7.54559
# [159]#011train-rmse:20.73853#011validation-rmse:7.57492
# [160]#011train-rmse:20.67511#011validation-rmse:7.58317
# [161]#011train-rmse:20.67385#011validation-rmse:7.58439
# [162]#011train-rmse:20.67835#011validation-rmse:7.56255
# [163]#011train-rmse:20.68069#011validation-rmse:7.56813
# [164]#011train-rmse:20.66275#011validation-rmse:7.61760
# [165]#011train-rmse:20.66868#011validation-rmse:7.66693
# [166]#011train-rmse:20.67381#011validation-rmse:7.66885
# [167]#011train-rmse:20.66079#011validation-rmse:7.67262
# [168]#011train-rmse:20.68119#011validation-rmse:7.48260
# [169]#011train-rmse:20.67829#011validation-rmse:7.49940
# [170]#011train-rmse:20.67495#011validation-rmse:7.60230
# [171]#011train-rmse:20.67929#011validation-rmse:7.51782
# [172]#011train-rmse:20.66610#011validation-rmse:7.52353
# [173]#011train-rmse:20.66476#011validation-rmse:7.51517
# [174]#011train-rmse:20.65920#011validation-rmse:7.50827
# [175]#011train-rmse:20.61835#011validation-rmse:7.71652
# [176]#011train-rmse:20.61967#011validation-rmse:7.72164
# [177]#011train-rmse:20.62301#011validation-rmse:7.64378
# [178]#011train-rmse:20.62103#011validation-rmse:7.63848
# [179]#011train-rmse:20.62030#011validation-rmse:7.64548
# [180]#011train-rmse:20.61386#011validation-rmse:7.64304
# [181]#011train-rmse:20.61701#011validation-rmse:7.63223
# [182]#011train-rmse:20.61150#011validation-rmse:7.62405
# [183]#011train-rmse:20.65567#011validation-rmse:7.42337
# [184]#011train-rmse:20.69288#011validation-rmse:7.30845
# [185]#011train-rmse:20.63985#011validation-rmse:7.58247
# [186]#011train-rmse:20.63578#011validation-rmse:7.59586
# [187]#011train-rmse:20.63607#011validation-rmse:7.59961
# [188]#011train-rmse:20.64463#011validation-rmse:7.56924
# [189]#011train-rmse:20.64160#011validation-rmse:7.57621
# [190]#011train-rmse:20.67702#011validation-rmse:7.43190
# [191]#011train-rmse:20.64595#011validation-rmse:7.52548
# [192]#011train-rmse:20.64880#011validation-rmse:7.50834
# [193]#011train-rmse:20.62481#011validation-rmse:7.79941
# [194]#011train-rmse:20.60130#011validation-rmse:8.05349
# [195]#011train-rmse:20.60578#011validation-rmse:8.04925
# [196]#011train-rmse:20.57857#011validation-rmse:8.20776
# [197]#011train-rmse:20.57913#011validation-rmse:7.84577
# [198]#011train-rmse:20.58072#011validation-rmse:7.74528
# [199]#011train-rmse:20.57731#011validation-rmse:7.74398
# [200]#011train-rmse:20.57977#011validation-rmse:7.70401
# [201]#011train-rmse:20.51520#011validation-rmse:8.03310
# [202]#011train-rmse:20.50761#011validation-rmse:8.03987
# [203]#011train-rmse:20.52485#011validation-rmse:7.88843
# [204]#011train-rmse:20.52730#011validation-rmse:7.88276
# [205]#011train-rmse:20.48837#011validation-rmse:8.10301
# [206]#011train-rmse:20.41913#011validation-rmse:8.15129
# [207]#011train-rmse:20.41798#011validation-rmse:8.14738
# [208]#011train-rmse:20.41406#011validation-rmse:8.15875
# [209]#011train-rmse:20.44196#011validation-rmse:8.03640
# [210]#011train-rmse:20.43686#011validation-rmse:8.12407
# [211]#011train-rmse:20.43546#011validation-rmse:8.13321
# [212]#011train-rmse:20.42443#011validation-rmse:8.14243
# [213]#011train-rmse:20.35739#011validation-rmse:8.17839
# [214]#011train-rmse:20.35714#011validation-rmse:8.18043
# [215]#011train-rmse:20.35058#011validation-rmse:8.24240
# [216]#011train-rmse:20.35071#011validation-rmse:8.23818
# [217]#011train-rmse:20.34858#011validation-rmse:8.24631
# [218]#011train-rmse:20.34861#011validation-rmse:8.26849
# [219]#011train-rmse:20.34773#011validation-rmse:8.27045
# [220]#011train-rmse:20.36788#011validation-rmse:8.13429
# [221]#011train-rmse:20.36708#011validation-rmse:8.15137
# [222]#011train-rmse:20.35243#011validation-rmse:8.18231
# [223]#011train-rmse:20.35628#011validation-rmse:8.17951
# [224]#011train-rmse:20.36051#011validation-rmse:8.17740
# [225]#011train-rmse:20.35328#011validation-rmse:8.17702
# [226]#011train-rmse:20.36932#011validation-rmse:8.06331
# [227]#011train-rmse:20.36911#011validation-rmse:8.07074
# [228]#011train-rmse:20.36690#011validation-rmse:8.07952
# [229]#011train-rmse:20.36371#011validation-rmse:8.10313
# [230]#011train-rmse:20.36647#011validation-rmse:8.10162
# [231]#011train-rmse:20.35686#011validation-rmse:8.15888
# [232]#011train-rmse:20.35803#011validation-rmse:8.10113
# [233]#011train-rmse:20.34471#011validation-rmse:8.14382
# [234]#011train-rmse:20.36336#011validation-rmse:7.95790
# [235]#011train-rmse:20.36674#011validation-rmse:7.98829
# [236]#011train-rmse:20.39554#011validation-rmse:7.88807
# [237]#011train-rmse:20.38931#011validation-rmse:7.93931
# [238]#011train-rmse:20.34441#011validation-rmse:8.06184
# [239]#011train-rmse:20.34350#011validation-rmse:8.06381
# [240]#011train-rmse:20.34542#011validation-rmse:8.07386
# [241]#011train-rmse:20.34172#011validation-rmse:7.99192
# [242]#011train-rmse:20.28787#011validation-rmse:7.96030
# [243]#011train-rmse:20.21463#011validation-rmse:8.11925
# [244]#011train-rmse:20.23361#011validation-rmse:7.95264
# [245]#011train-rmse:20.22774#011validation-rmse:7.82664
# [246]#011train-rmse:20.22703#011validation-rmse:7.86463
# [247]#011train-rmse:20.23113#011validation-rmse:7.91183
# [248]#011train-rmse:20.23420#011validation-rmse:7.90925
# [249]#011train-rmse:20.22971#011validation-rmse:7.90392
# [250]#011train-rmse:20.22723#011validation-rmse:7.91341
# [251]#011train-rmse:20.21617#011validation-rmse:7.84819
# [252]#011train-rmse:20.18097#011validation-rmse:8.12273
# [253]#011train-rmse:20.17184#011validation-rmse:8.12380
# [254]#011train-rmse:20.17042#011validation-rmse:8.13963
# [255]#011train-rmse:20.16730#011validation-rmse:8.14294
# [256]#011train-rmse:20.16353#011validation-rmse:8.13880
# [257]#011train-rmse:20.16340#011validation-rmse:8.13628
# [258]#011train-rmse:20.16612#011validation-rmse:8.14007
# [259]#011train-rmse:20.17022#011validation-rmse:7.96074
# [260]#011train-rmse:20.16920#011validation-rmse:7.96220
# [261]#011train-rmse:20.16896#011validation-rmse:7.96040
# [262]#011train-rmse:20.17533#011validation-rmse:7.89320
# [263]#011train-rmse:20.20652#011validation-rmse:7.79355
# [264]#011train-rmse:20.19108#011validation-rmse:7.89130
# [265]#011train-rmse:20.19636#011validation-rmse:7.83020
# [266]#011train-rmse:20.19888#011validation-rmse:7.83106
# [267]#011train-rmse:20.23660#011validation-rmse:7.67525
# [268]#011train-rmse:20.15047#011validation-rmse:7.87269
# [269]#011train-rmse:20.10657#011validation-rmse:8.06400
# [270]#011train-rmse:20.10516#011validation-rmse:8.07368
# [271]#011train-rmse:20.10689#011validation-rmse:8.07353
# [272]#011train-rmse:20.10316#011validation-rmse:8.06819
# [273]#011train-rmse:20.10493#011validation-rmse:8.06838
# [274]#011train-rmse:20.10099#011validation-rmse:8.07262
# [275]#011train-rmse:20.09995#011validation-rmse:8.07654
# [276]#011train-rmse:20.09548#011validation-rmse:8.07564
# [277]#011train-rmse:20.09396#011validation-rmse:8.07696
# [278]#011train-rmse:20.09409#011validation-rmse:8.07981
# [279]#011train-rmse:20.09360#011validation-rmse:8.08177
# [280]#011train-rmse:20.09455#011validation-rmse:8.08263
# [281]#011train-rmse:20.09527#011validation-rmse:8.02670
# [282]#011train-rmse:20.09484#011validation-rmse:8.02897
# [283]#011train-rmse:20.12498#011validation-rmse:7.86474
# [284]#011train-rmse:20.12198#011validation-rmse:7.87759
# [285]#011train-rmse:20.12044#011validation-rmse:7.87754
# [286]#011train-rmse:20.08315#011validation-rmse:8.10436
# [287]#011train-rmse:20.08474#011validation-rmse:8.10554
# [288]#011train-rmse:20.08631#011validation-rmse:8.10965
# [289]#011train-rmse:20.10690#011validation-rmse:7.91548
# [290]#011train-rmse:20.08151#011validation-rmse:8.07251
# [291]#011train-rmse:20.08191#011validation-rmse:8.28098
# [292]#011train-rmse:20.08043#011validation-rmse:8.27996
# [293]#011train-rmse:20.07950#011validation-rmse:8.08926
# [294]#011train-rmse:20.07881#011validation-rmse:8.08893
# [295]#011train-rmse:19.98936#011validation-rmse:8.25752
# [296]#011train-rmse:19.98284#011validation-rmse:8.26847
# [297]#011train-rmse:19.97758#011validation-rmse:8.33204
# [298]#011train-rmse:19.98471#011validation-rmse:8.05657
# [299]#011train-rmse:19.98762#011validation-rmse:8.05788
# [300]#011train-rmse:19.98666#011validation-rmse:8.06182
# [301]#011train-rmse:19.98390#011validation-rmse:8.05902
# [302]#011train-rmse:19.99194#011validation-rmse:7.98911
# [303]#011train-rmse:19.98534#011validation-rmse:8.00120
# [304]#011train-rmse:19.95574#011validation-rmse:8.00039
# [305]#011train-rmse:19.93176#011validation-rmse:7.94705
# [306]#011train-rmse:19.88981#011validation-rmse:8.11760
# [307]#011train-rmse:19.88806#011validation-rmse:8.12017
# [308]#011train-rmse:19.88704#011validation-rmse:8.13900
# [309]#011train-rmse:19.87937#011validation-rmse:8.20597
# [310]#011train-rmse:19.88073#011validation-rmse:8.20402
# [311]#011train-rmse:19.88224#011validation-rmse:8.20364
# [312]#011train-rmse:19.89757#011validation-rmse:8.01820
# [313]#011train-rmse:19.89618#011validation-rmse:8.02569
# [314]#011train-rmse:19.89628#011validation-rmse:8.03001
# [315]#011train-rmse:19.88107#011validation-rmse:8.31180
# [316]#011train-rmse:19.91221#011validation-rmse:8.13409
# [317]#011train-rmse:19.88198#011validation-rmse:8.15272
# [318]#011train-rmse:19.88128#011validation-rmse:8.16132
# [319]#011train-rmse:19.83660#011validation-rmse:8.16455
# [320]#011train-rmse:19.83550#011validation-rmse:8.13398
# [321]#011train-rmse:19.83317#011validation-rmse:8.19811
# [322]#011train-rmse:19.82534#011validation-rmse:8.20177
# [323]#011train-rmse:19.83051#011validation-rmse:8.19826
# [324]#011train-rmse:19.88205#011validation-rmse:8.00840
# [325]#011train-rmse:19.84621#011validation-rmse:8.25479
# [326]#011train-rmse:19.84481#011validation-rmse:8.24241
# [327]#011train-rmse:19.84071#011validation-rmse:8.28473
# [328]#011train-rmse:19.83054#011validation-rmse:8.28664
# [329]#011train-rmse:19.82726#011validation-rmse:8.28524
# [330]#011train-rmse:19.86886#011validation-rmse:8.15174
# [331]#011train-rmse:19.86936#011validation-rmse:8.14529
# [332]#011train-rmse:19.90187#011validation-rmse:8.02591
# [333]#011train-rmse:19.90430#011validation-rmse:7.99059
# [334]#011train-rmse:19.82500#011validation-rmse:8.19531
# [335]#011train-rmse:19.82482#011validation-rmse:8.24342
# [336]#011train-rmse:19.86707#011validation-rmse:8.11041
# [337]#011train-rmse:19.81893#011validation-rmse:8.22500
# [338]#011train-rmse:19.79062#011validation-rmse:8.23377
# [339]#011train-rmse:19.78668#011validation-rmse:8.33218
# [340]#011train-rmse:19.72760#011validation-rmse:8.53060
# [341]#011train-rmse:19.72846#011validation-rmse:8.48106
# [342]#011train-rmse:19.74868#011validation-rmse:8.31574
# [343]#011train-rmse:19.74033#011validation-rmse:8.35164
# [344]#011train-rmse:19.69076#011validation-rmse:8.29979
# [345]#011train-rmse:19.68078#011validation-rmse:8.31415
# [346]#011train-rmse:19.66783#011validation-rmse:8.39160
# [347]#011train-rmse:19.66648#011validation-rmse:8.39834
# [348]#011train-rmse:19.68655#011validation-rmse:8.21158
# [349]#011train-rmse:19.68641#011validation-rmse:8.21290
# [350]#011train-rmse:19.70423#011validation-rmse:8.05302
# [351]#011train-rmse:19.66362#011validation-rmse:8.23175
# [352]#011train-rmse:19.66399#011validation-rmse:8.23202
# [353]#011train-rmse:19.66061#011validation-rmse:8.24066
# [354]#011train-rmse:19.63795#011validation-rmse:8.32099
# [355]#011train-rmse:19.63966#011validation-rmse:8.22244
# [356]#011train-rmse:19.63692#011validation-rmse:8.22683
# [357]#011train-rmse:19.63636#011validation-rmse:8.30158
# [358]#011train-rmse:19.66007#011validation-rmse:8.15974
# [359]#011train-rmse:19.63548#011validation-rmse:8.36427
# [360]#011train-rmse:19.63933#011validation-rmse:8.36151
# [361]#011train-rmse:19.63436#011validation-rmse:8.36022
# [362]#011train-rmse:19.63204#011validation-rmse:8.37279
# [363]#011train-rmse:19.63150#011validation-rmse:8.37399
# [364]#011train-rmse:19.63227#011validation-rmse:8.37305
# [365]#011train-rmse:19.65316#011validation-rmse:8.20415
# [366]#011train-rmse:19.65111#011validation-rmse:8.25639
# [367]#011train-rmse:19.63374#011validation-rmse:8.43656
# [368]#011train-rmse:19.63466#011validation-rmse:8.45027
# [369]#011train-rmse:19.59247#011validation-rmse:8.50318
# [370]#011train-rmse:19.59099#011validation-rmse:8.49306
# [371]#011train-rmse:19.58648#011validation-rmse:8.49527
# [372]#011train-rmse:19.60733#011validation-rmse:8.30227
# [373]#011train-rmse:19.60936#011validation-rmse:8.24355
# [374]#011train-rmse:19.60564#011validation-rmse:8.28073
# [375]#011train-rmse:19.56290#011validation-rmse:8.43322
# [376]#011train-rmse:19.56327#011validation-rmse:8.43169
# [377]#011train-rmse:19.56344#011validation-rmse:8.43001
# [378]#011train-rmse:19.56150#011validation-rmse:8.44099
# [379]#011train-rmse:19.54670#011validation-rmse:8.48748
# [380]#011train-rmse:19.54528#011validation-rmse:8.48969
# [381]#011train-rmse:19.54076#011validation-rmse:8.49173
# [382]#011train-rmse:19.55803#011validation-rmse:8.31585
# [383]#011train-rmse:19.55571#011validation-rmse:8.33876
# [384]#011train-rmse:19.55526#011validation-rmse:8.33900
# [385]#011train-rmse:19.55864#011validation-rmse:8.34129
# [386]#011train-rmse:19.55577#011validation-rmse:8.34063
# [387]#011train-rmse:19.55765#011validation-rmse:8.33894
# [388]#011train-rmse:19.55526#011validation-rmse:8.34285
# [389]#011train-rmse:19.57978#011validation-rmse:8.21325
# [390]#011train-rmse:19.57374#011validation-rmse:8.21174
# [391]#011train-rmse:19.62092#011validation-rmse:8.06032
# [392]#011train-rmse:19.57918#011validation-rmse:8.19512
# [393]#011train-rmse:19.55020#011validation-rmse:8.45459
# [394]#011train-rmse:19.58482#011validation-rmse:8.15000
# [395]#011train-rmse:19.62125#011validation-rmse:7.96944
# [396]#011train-rmse:19.43657#011validation-rmse:8.22118
# [397]#011train-rmse:19.43734#011validation-rmse:8.21949
# [398]#011train-rmse:19.47147#011validation-rmse:8.10730
# [399]#011train-rmse:19.42064#011validation-rmse:8.25123
# [400]#011train-rmse:19.41667#011validation-rmse:8.31418
# [401]#011train-rmse:19.41305#011validation-rmse:8.35575
# [402]#011train-rmse:19.41355#011validation-rmse:8.36252
#
# 2023-08-31 04:21:30 Uploading - Uploading generated training model[403]#011train-rmse:19.41378#011validation-rmse:8.36414
# [404]#011train-rmse:19.44073#011validation-rmse:8.18328
# [405]#011train-rmse:19.42058#011validation-rmse:8.44053
# [406]#011train-rmse:19.37162#011validation-rmse:8.68518
# [407]#011train-rmse:19.34970#011validation-rmse:8.85516
# [408]#011train-rmse:19.35106#011validation-rmse:8.85331
# [409]#011train-rmse:19.34853#011validation-rmse:8.85859
# [410]#011train-rmse:19.32177#011validation-rmse:8.88295
# [411]#011train-rmse:19.32089#011validation-rmse:8.88283
# [412]#011train-rmse:19.32094#011validation-rmse:8.88063
# [413]#011train-rmse:19.35574#011validation-rmse:8.65925
# [414]#011train-rmse:19.38516#011validation-rmse:8.53581
# [415]#011train-rmse:19.36118#011validation-rmse:8.60154
# [416]#011train-rmse:19.35984#011validation-rmse:8.60060
# [417]#011train-rmse:19.33412#011validation-rmse:8.87076
# [418]#011train-rmse:19.35665#011validation-rmse:8.69170
# [419]#011train-rmse:19.35146#011validation-rmse:8.74263
# [420]#011train-rmse:19.32398#011validation-rmse:8.99935
# [421]#011train-rmse:19.32259#011validation-rmse:9.00648
# [422]#011train-rmse:19.30561#011validation-rmse:9.03949
# [423]#011train-rmse:19.30886#011validation-rmse:9.04152
# [424]#011train-rmse:19.30936#011validation-rmse:9.03901
# [425]#011train-rmse:19.31172#011validation-rmse:8.96735
# [426]#011train-rmse:19.30295#011validation-rmse:8.96742
# [427]#011train-rmse:19.30216#011validation-rmse:8.96344
# [428]#011train-rmse:19.30836#011validation-rmse:8.61264
# [429]#011train-rmse:19.28077#011validation-rmse:8.71399
# [430]#011train-rmse:19.29938#011validation-rmse:8.52541
# [431]#011train-rmse:19.29846#011validation-rmse:8.36057
# [432]#011train-rmse:19.27437#011validation-rmse:8.43134
# [433]#011train-rmse:19.31165#011validation-rmse:8.31361
# [434]#011train-rmse:19.30230#011validation-rmse:8.34631
# [435]#011train-rmse:19.29236#011validation-rmse:8.38715
# [436]#011train-rmse:19.27744#011validation-rmse:8.43561
# [437]#011train-rmse:19.19628#011validation-rmse:8.61961
# [438]#011train-rmse:19.19542#011validation-rmse:8.62445
# [439]#011train-rmse:19.23040#011validation-rmse:8.41757
# [440]#011train-rmse:19.22901#011validation-rmse:8.42206
# [441]#011train-rmse:19.21851#011validation-rmse:8.48996
# [442]#011train-rmse:19.17818#011validation-rmse:8.65131
# [443]#011train-rmse:19.20807#011validation-rmse:8.46785
# [444]#011train-rmse:19.20781#011validation-rmse:8.46796
# [445]#011train-rmse:19.20594#011validation-rmse:8.46797
# [446]#011train-rmse:19.20626#011validation-rmse:8.48502
# [447]#011train-rmse:19.20637#011validation-rmse:8.49062
# [448]#011train-rmse:19.14981#011validation-rmse:8.91661
# [449]#011train-rmse:19.16263#011validation-rmse:8.61700
# [450]#011train-rmse:19.16182#011validation-rmse:8.61626
# [451]#011train-rmse:19.16199#011validation-rmse:8.61769
# [452]#011train-rmse:19.15874#011validation-rmse:8.61093
# [453]#011train-rmse:19.14180#011validation-rmse:8.83330
# [454]#011train-rmse:19.13816#011validation-rmse:8.84818
# [455]#011train-rmse:19.13671#011validation-rmse:8.85056
# [456]#011train-rmse:19.15639#011validation-rmse:8.65121
# [457]#011train-rmse:19.15130#011validation-rmse:8.65696
# [458]#011train-rmse:19.10781#011validation-rmse:8.91498
# [459]#011train-rmse:19.08504#011validation-rmse:8.90003
# [460]#011train-rmse:19.08328#011validation-rmse:8.90684
# [461]#011train-rmse:19.08452#011validation-rmse:8.90503
# [462]#011train-rmse:19.08144#011validation-rmse:8.90685
# [463]#011train-rmse:19.07259#011validation-rmse:8.59260
# [464]#011train-rmse:19.07420#011validation-rmse:8.60886
# [465]#011train-rmse:19.07248#011validation-rmse:8.60765
# [466]#011train-rmse:19.07178#011validation-rmse:8.60991
# [467]#011train-rmse:19.09972#011validation-rmse:8.45144
# [468]#011train-rmse:19.04996#011validation-rmse:8.56410
# [469]#011train-rmse:19.04847#011validation-rmse:8.61875
# [470]#011train-rmse:19.04874#011validation-rmse:8.61774
# [471]#011train-rmse:19.07917#011validation-rmse:8.46733
# [472]#011train-rmse:19.07248#011validation-rmse:8.47318
# [473]#011train-rmse:19.10318#011validation-rmse:8.30126
# [474]#011train-rmse:19.11644#011validation-rmse:8.24886
# [475]#011train-rmse:19.15396#011validation-rmse:8.13973
# [476]#011train-rmse:19.14561#011validation-rmse:8.15994
# [477]#011train-rmse:19.14502#011validation-rmse:8.16982
# [478]#011train-rmse:19.13057#011validation-rmse:8.21913
# [479]#011train-rmse:19.12707#011validation-rmse:8.29376
# [480]#011train-rmse:19.12048#011validation-rmse:8.30777
# [481]#011train-rmse:19.11865#011validation-rmse:8.30535
# [482]#011train-rmse:19.11708#011validation-rmse:8.30495
# [483]#011train-rmse:19.11457#011validation-rmse:8.32740
# [484]#011train-rmse:19.11464#011validation-rmse:8.32572
# [485]#011train-rmse:19.15250#011validation-rmse:8.20340
# [486]#011train-rmse:19.10262#011validation-rmse:8.48240
# [487]#011train-rmse:19.11687#011validation-rmse:8.32220
# [488]#011train-rmse:19.11292#011validation-rmse:8.36318
# [489]#011train-rmse:19.11209#011validation-rmse:8.36311
# [490]#011train-rmse:19.11238#011validation-rmse:8.36214
# [491]#011train-rmse:19.10059#011validation-rmse:8.35815
# [492]#011train-rmse:19.09274#011validation-rmse:8.40040
# [493]#011train-rmse:19.09217#011validation-rmse:8.39854
# [494]#011train-rmse:19.12838#011validation-rmse:8.28767
# [495]#011train-rmse:19.12357#011validation-rmse:8.34298
# [496]#011train-rmse:19.15103#011validation-rmse:8.18497
# [497]#011train-rmse:19.09570#011validation-rmse:8.49877
# [498]#011train-rmse:19.09226#011validation-rmse:8.49590
# [499]#011train-rmse:19.12026#011validation-rmse:8.37927
#
# 2023-08-31 04:21:46 Completed - Training job completed
# Training seconds: 152
# Billable seconds: 152

# %% [markdown]
# ## Host the model

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2023-08-31-04-22-13-849
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2023-08-31-04-22-13-849
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2023-08-31-04-22-13-849
# ------!

# %% [markdown]
# ## Test the end point

# %%
xgb_predictor.serializer = sagemaker.serializers.CSVSerializer()

# %%
def predict(data, predictor, rows=500 ):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

# %%
data = test_data.drop(['trip_total'], axis=1).to_numpy()

# %%
# Show the first 10 rows prediction and true value
for i, d in enumerate(data[:10]):
    # print(d)
    pred = predict(d, xgb_predictor)[0]
    true_value = test_data["trip_total"].reset_index().iloc[i, 1]
    print("Prediction value", pred, "and true value:", true_value)
# Out:
# Prediction value 9.125707626342773 and true value: 10.49
# Prediction value 58.38532257080078 and true value: 58.5
# Prediction value 43.28390121459961 and true value: 42.9
# Prediction value 48.146820068359375 and true value: 45.0
# Prediction value 40.64889907836914 and true value: 40.75
# Prediction value 28.783700942993164 and true value: 28.0
# Prediction value 57.06315612792969 and true value: 58.6
# Prediction value 11.045339584350586 and true value: 12.0
# Prediction value 48.19758987426758 and true value: 48.75
# Prediction value 8.260760307312012 and true value: 8.5

# %% [markdown]
# ## Cleanup

# %%
# xgb_predictor.delete_endpoints(delete_endpoint_config=True)
