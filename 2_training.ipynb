# %% [markdown]
# ## Load packages

# %%
# Define IAM role
import boto3
import re
from sagemaker import get_execution_role
from sagemaker.session import Session
from sagemaker.feature_store.feature_group import FeatureGroup
import yaml
import numpy as np                                # For matrix operations and numerical processing
import pandas as pd                               # For munging tabular data
import matplotlib.pyplot as plt                   # For charts and visualizations
from IPython.display import Image                 # For displaying images in the notebook
from IPython.display import display               # For displaying outputs in the notebook
from time import gmtime, strftime                 # For labeling SageMaker models, endpoints, etc.
import sys                                        # For writing outputs to notebook
import math                                       # For ceiling function
import json                                       # For parsing hosting outputs
import os                                         # For manipulating filepath names
import sagemaker 
import zipfile     # Amazon SageMaker's Python SDK provides many helper functions
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Load Configs

# %%
role = get_execution_role()
region = boto3.Session().region_name

feature_group_name = "taxi-feature-group-no-encoding"
bucket = sagemaker.Session().default_bucket()
prefix = "sagemaker/xgboost_model"

# %%
bucket
# Out:
# 'sagemaker-ap-southeast-2-949757562939'

# %% [markdown]
# ## Get data from Feature Store

# %%
# Connect to the Feature Store
boto_session = boto3.Session(region_name=region)

sagemaker_client = boto_session.client(service_name='sagemaker', region_name=region)
featurestore_runtime = boto_session.client(service_name='sagemaker-featurestore-runtime', region_name=region)

feature_store_session = Session(
    boto_session=boto_session,
    sagemaker_client=sagemaker_client,
    sagemaker_featurestore_runtime_client=featurestore_runtime
)

feature_group = FeatureGroup(name=feature_group_name, sagemaker_session=feature_store_session)

# %%
# Build SQL query to features group
fs_query = feature_group.athena_query()
fs_table = fs_query.table_name
query_string = 'SELECT * FROM "'+fs_table+'"'
print('Running ' + query_string)
# Out:
# Running SELECT * FROM "taxi_feature_group_no_encoding_1693400933"

# %%
# Run Athena query. The output is loaded to a Pandas dataframe.
fs_query.run(query_string=query_string, output_location='s3://'+bucket+'/'+prefix+'/fs_query_results/')
fs_query.wait()
model_data = fs_query.as_dataframe()

# %%
model_data = model_data.drop(['fs_id', 'fs_time', 'write_time', 'api_invocation_time', 'is_deleted'], axis=1)

# %%
model_data.head()
# Out:
#    trip_seconds  trip_miles  pickup_community_area  dropoff_community_area  \
# 0        1697.0       12.08                     56                       8
# 1         660.0        0.20                     32                       7
# 2         535.0        0.87                      6                       6
# 3         800.0        1.99                     32                       8
# 4        1140.0        0.00                     56                      35
#
#    tips  tolls  extras  trip_total payment_type  pickup_centroid_latitude  \
# 0  0.07      0       4       36.57  credit_card                 41.785999
# 1  4.50      0       1       17.00  credit_card                 41.878866
# 2  3.00      0       0       10.25  credit_card                 41.944227
# 3  3.28      0       2       15.67       mobile                 41.878866
# 4  6.30      0       5       37.30  credit_card                 41.792592
#
#    pickup_centroid_longitude  dropoff_centroid_latitude  \
# 0                 -87.750934                  41.892042
# 1                 -87.625192                  41.922686
# 2                 -87.655998                  41.944227
# 3                 -87.625192                  41.899602
# 4                 -87.769615                  41.835118
#
#    dropoff_centroid_longitude  start_month  start_day  start_hour  \
# 0                  -87.631864            6         23          23
# 1                  -87.649489            6         23          23
# 2                  -87.655998            6         23          23
# 3                  -87.633308            6         23          23
# 4                  -87.618678            6         23          23
#
#    start_minute
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
model_data.shape
# Out:
# (174724, 17)

# %% [markdown]
# ## Prepare Dataset for Training, Test, and Validation

# %%
# Randomly sort the data then split out first 70%, second 20%, and last 10%
train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data)), int(0.9 * len(model_data))])

# %%
# Move the target variable to the first column
pd.concat([train_data['trip_total'], train_data.drop(['trip_total'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False)
pd.concat([validation_data['trip_total'], validation_data.drop(['trip_total'], axis=1)], axis=1).to_csv('validation.csv', index=False, header=False)

# %%
# Upload the training and validation dataset into S3 bucket.
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')

# %% [markdown]
# ## Training

# %%
# Select the xgboost built in container
container = sagemaker.image_uris.retrieve(region=region, framework='xgboost', version='1.7-1')

# Get the input and validation path
s3_input_train = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

sess = sagemaker.Session()

hyperparameters = {
        "max_depth":"5",
        "eta":"0.2",
        "gamma":"4",
        "min_child_weight":"6",
        "subsample":"0.7",
        "objective":"reg:squarederror",
        "num_round":"500"}

xgb = sagemaker.estimator.Estimator(container,
                                    role, 
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess,
                                    hyperparameters=hyperparameters
                                   )

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-08-31-00-53-30-347
# 2023-08-31 00:53:30 Starting - Starting the training job...
# 2023-08-31 00:53:45 Starting - Preparing the instances for training......
# 2023-08-31 00:54:54 Downloading - Downloading input data...
# 2023-08-31 00:55:19 Training - Downloading the training image......
# 2023-08-31 00:56:10 Training - Training image download completed. Training in progress.[2023-08-31 00:56:23.891 ip-10-0-67-89.ap-southeast-2.compute.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-08-31 00:56:23.926 ip-10-0-67-89.ap-southeast-2.compute.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-08-31:00:56:24:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-08-31:00:56:24:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-08-31:00:56:24:INFO] No GPUs detected (normal if no gpus installed)
# [2023-08-31:00:56:24:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-08-31:00:56:24:INFO] Determined 0 GPU(s) available on the instance.
# [2023-08-31:00:56:24:INFO] Determined delimiter of CSV input is ','
# [2023-08-31:00:56:24:INFO] Determined delimiter of CSV input is ','
# [2023-08-31:00:56:24:INFO] files path: /opt/ml/input/data/train
# [2023-08-31:00:56:24:INFO] Determined delimiter of CSV input is ','
# [2023-08-31:00:56:24:INFO] files path: /opt/ml/input/data/validation
# [2023-08-31:00:56:24:INFO] Determined delimiter of CSV input is ','
# [2023-08-31:00:56:24:INFO] Single node training.
# [2023-08-31:00:56:24:INFO] Train matrix has 122306 rows and 16 columns
# [2023-08-31:00:56:24:INFO] Validation matrix has 34945 rows
# [2023-08-31 00:56:24.552 ip-10-0-67-89.ap-southeast-2.compute.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-08-31 00:56:24.553 ip-10-0-67-89.ap-southeast-2.compute.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-08-31 00:56:24.554 ip-10-0-67-89.ap-southeast-2.compute.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-08-31 00:56:24.554 ip-10-0-67-89.ap-southeast-2.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-08-31:00:56:24:INFO] Debug hook created from config
# [2023-08-31 00:56:24.759 ip-10-0-67-89.ap-southeast-2.compute.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-08-31 00:56:24.762 ip-10-0-67-89.ap-southeast-2.compute.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train
# [206]#011train-rmse:21.05461#011validation-rmse:8.30707
# [207]#011train-rmse:21.03019#011validation-rmse:8.38430
# [208]#011train-rmse:21.03155#011validation-rmse:8.36755
# [209]#011train-rmse:21.02370#011validation-rmse:8.42566
# [210]#011train-rmse:20.97034#011validation-rmse:8.73084
# [211]#011train-rmse:20.96982#011validation-rmse:8.75273
# [212]#011train-rmse:20.96745#011validation-rmse:8.66410
# [213]#011train-rmse:20.97785#011validation-rmse:8.65113
# [214]#011train-rmse:20.98667#011validation-rmse:8.48588
# [215]#011train-rmse:20.97098#011validation-rmse:8.51292
# [216]#011train-rmse:20.98992#011validation-rmse:8.49716
# [217]#011train-rmse:21.03244#011validation-rmse:8.43810
# [218]#011train-rmse:21.03498#011validation-rmse:8.45818
# [219]#011train-rmse:20.99538#011validation-rmse:8.42176
# [220]#011train-rmse:20.96610#011validation-rmse:8.62643
# [221]#011train-rmse:20.99215#011validation-rmse:8.46177
# [222]#011train-rmse:20.96970#011validation-rmse:8.53768
# [223]#011train-rmse:20.97314#011validation-rmse:8.54368
# [224]#011train-rmse:20.96383#011validation-rmse:8.50316
# [225]#011train-rmse:20.99436#011validation-rmse:8.41119
# [226]#011train-rmse:20.95413#011validation-rmse:8.41520
# [227]#011train-rmse:20.91866#011validation-rmse:8.56204
# [228]#011train-rmse:20.92198#011validation-rmse:8.58477
# [229]#011train-rmse:20.91895#011validation-rmse:8.57750
# [230]#011train-rmse:20.90117#011validation-rmse:8.63949
# [231]#011train-rmse:20.86846#011validation-rmse:8.72083
# [232]#011train-rmse:20.88206#011validation-rmse:8.75908
# [233]#011train-rmse:20.87031#011validation-rmse:8.80421
# [234]#011train-rmse:20.86686#011validation-rmse:8.81324
# [235]#011train-rmse:20.87638#011validation-rmse:8.80976
# [236]#011train-rmse:20.86636#011validation-rmse:8.83686
# [237]#011train-rmse:20.86013#011validation-rmse:8.84107
# [238]#011train-rmse:20.86717#011validation-rmse:8.83959
# [239]#011train-rmse:20.85639#011validation-rmse:8.83634
# [240]#011train-rmse:20.77403#011validation-rmse:8.67341
# [241]#011train-rmse:20.77290#011validation-rmse:8.77785
# [242]#011train-rmse:20.70317#011validation-rmse:8.80658
# [243]#011train-rmse:20.75083#011validation-rmse:9.05823
# [244]#011train-rmse:20.74041#011validation-rmse:9.04435
# [245]#011train-rmse:20.73226#011validation-rmse:9.10339
# [246]#011train-rmse:20.73388#011validation-rmse:9.14752
# [247]#011train-rmse:20.73291#011validation-rmse:9.14761
# [248]#011train-rmse:20.72506#011validation-rmse:9.07661
# [249]#011train-rmse:20.70507#011validation-rmse:8.75585
# [250]#011train-rmse:20.74322#011validation-rmse:8.55257
# [251]#011train-rmse:20.73867#011validation-rmse:8.58706
# [252]#011train-rmse:20.73693#011validation-rmse:8.60701
# [253]#011train-rmse:20.73595#011validation-rmse:8.60624
# [254]#011train-rmse:20.73710#011validation-rmse:8.57067
# [255]#011train-rmse:20.72045#011validation-rmse:8.78025
# [256]#011train-rmse:20.71998#011validation-rmse:8.79120
# [257]#011train-rmse:20.71609#011validation-rmse:8.72193
# [258]#011train-rmse:20.73477#011validation-rmse:8.60552
# [259]#011train-rmse:20.73356#011validation-rmse:8.62992
# [260]#011train-rmse:20.73005#011validation-rmse:8.66235
# [261]#011train-rmse:20.72494#011validation-rmse:8.66502
# [262]#011train-rmse:20.72291#011validation-rmse:8.66102
# [263]#011train-rmse:20.73914#011validation-rmse:8.44974
# [264]#011train-rmse:20.73454#011validation-rmse:8.47702
# [265]#011train-rmse:20.69759#011validation-rmse:8.72903
# [266]#011train-rmse:20.69759#011validation-rmse:8.76012
# [267]#011train-rmse:20.70916#011validation-rmse:8.62447
# [268]#011train-rmse:20.72564#011validation-rmse:8.48627
# [269]#011train-rmse:20.71109#011validation-rmse:8.53414
# [270]#011train-rmse:20.71073#011validation-rmse:8.54090
# [271]#011train-rmse:20.71151#011validation-rmse:8.60303
# [272]#011train-rmse:20.70917#011validation-rmse:8.64543
# [273]#011train-rmse:20.70804#011validation-rmse:8.66861
# [274]#011train-rmse:20.70747#011validation-rmse:8.75034
# [275]#011train-rmse:20.74039#011validation-rmse:8.69848
# [276]#011train-rmse:20.77458#011validation-rmse:8.52713
# [277]#011train-rmse:20.81985#011validation-rmse:8.53139
# [278]#011train-rmse:20.77254#011validation-rmse:8.66100
# [279]#011train-rmse:20.77363#011validation-rmse:8.66451
# [280]#011train-rmse:20.72506#011validation-rmse:8.74322
# [281]#011train-rmse:20.72271#011validation-rmse:8.77842
# [282]#011train-rmse:20.71880#011validation-rmse:8.71456
# [283]#011train-rmse:20.74667#011validation-rmse:8.66558
# [284]#011train-rmse:20.74223#011validation-rmse:8.62066
# [285]#011train-rmse:20.78420#011validation-rmse:8.52720
# [286]#011train-rmse:20.73973#011validation-rmse:8.40389
# [287]#011train-rmse:20.76374#011validation-rmse:8.30255
# [288]#011train-rmse:20.67865#011validation-rmse:8.48889
# [289]#011train-rmse:20.67741#011validation-rmse:8.50049
# [290]#011train-rmse:20.67339#011validation-rmse:8.52849
# [291]#011train-rmse:20.67659#011validation-rmse:8.56547
# [292]#011train-rmse:20.70519#011validation-rmse:8.39826
# [293]#011train-rmse:20.74818#011validation-rmse:8.26456
# [294]#011train-rmse:20.64217#011validation-rmse:8.52304
# [295]#011train-rmse:20.64131#011validation-rmse:8.44591
# [296]#011train-rmse:20.63798#011validation-rmse:8.47397
# [297]#011train-rmse:20.65570#011validation-rmse:8.37650
# [298]#011train-rmse:20.65245#011validation-rmse:8.52147
# [299]#011train-rmse:20.64406#011validation-rmse:8.52339
# [300]#011train-rmse:20.64080#011validation-rmse:8.52232
# [301]#011train-rmse:20.64604#011validation-rmse:8.51929
# [302]#011train-rmse:20.63350#011validation-rmse:8.53667
# [303]#011train-rmse:20.60184#011validation-rmse:8.62803
# [304]#011train-rmse:20.54132#011validation-rmse:8.66074
# [305]#011train-rmse:20.53866#011validation-rmse:8.73920
# [306]#011train-rmse:20.53698#011validation-rmse:8.73386
# [307]#011train-rmse:20.52607#011validation-rmse:8.75370
# [308]#011train-rmse:20.52082#011validation-rmse:8.77518
# [309]#011train-rmse:20.51745#011validation-rmse:8.78981
# [310]#011train-rmse:20.48968#011validation-rmse:8.71310
# [311]#011train-rmse:20.48416#011validation-rmse:8.74329
# [312]#011train-rmse:20.48105#011validation-rmse:8.76829
# [313]#011train-rmse:20.47983#011validation-rmse:8.69792
# [314]#011train-rmse:20.48560#011validation-rmse:8.69988
# [315]#011train-rmse:20.50311#011validation-rmse:8.57881
# [316]#011train-rmse:20.53037#011validation-rmse:8.45197
# [317]#011train-rmse:20.48366#011validation-rmse:8.68153
# [318]#011train-rmse:20.47135#011validation-rmse:8.78785
# [319]#011train-rmse:20.42231#011validation-rmse:8.80909
# [320]#011train-rmse:20.42244#011validation-rmse:8.80973
# [321]#011train-rmse:20.42137#011validation-rmse:8.58645
# [322]#011train-rmse:20.41918#011validation-rmse:8.61821
# [323]#011train-rmse:20.38905#011validation-rmse:8.79954
# [324]#011train-rmse:20.38857#011validation-rmse:8.74511
# [325]#011train-rmse:20.38909#011validation-rmse:8.75649
# [326]#011train-rmse:20.40689#011validation-rmse:8.69357
# [327]#011train-rmse:20.40847#011validation-rmse:8.72510
# [328]#011train-rmse:20.40827#011validation-rmse:8.74895
# [329]#011train-rmse:20.41253#011validation-rmse:8.80229
# [330]#011train-rmse:20.41797#011validation-rmse:8.79276
# [331]#011train-rmse:20.40530#011validation-rmse:8.78635
# [332]#011train-rmse:20.40808#011validation-rmse:8.77961
# [333]#011train-rmse:20.39805#011validation-rmse:8.77309
# [334]#011train-rmse:20.39491#011validation-rmse:8.74529
# [335]#011train-rmse:20.39596#011validation-rmse:8.69080
# [336]#011train-rmse:20.39680#011validation-rmse:8.69988
# [337]#011train-rmse:20.38905#011validation-rmse:8.70611
# [338]#011train-rmse:20.42581#011validation-rmse:8.59639
# [339]#011train-rmse:20.46779#011validation-rmse:8.54036
# [340]#011train-rmse:20.46919#011validation-rmse:8.56064
# [341]#011train-rmse:20.46923#011validation-rmse:8.52587
# [342]#011train-rmse:20.50580#011validation-rmse:8.45945
# [343]#011train-rmse:20.44285#011validation-rmse:8.53650
# [344]#011train-rmse:20.48692#011validation-rmse:8.48360
# [345]#011train-rmse:20.51354#011validation-rmse:8.40350
# [346]#011train-rmse:20.43451#011validation-rmse:8.49489
# [347]#011train-rmse:20.40118#011validation-rmse:8.61524
# [348]#011train-rmse:20.42984#011validation-rmse:8.52422
# [349]#011train-rmse:20.42519#011validation-rmse:8.55321
# [350]#011train-rmse:20.47741#011validation-rmse:8.51117
# [351]#011train-rmse:20.47235#011validation-rmse:8.48625
# [352]#011train-rmse:20.47224#011validation-rmse:8.49864
# [353]#011train-rmse:20.43804#011validation-rmse:8.63200
# [354]#011train-rmse:20.43326#011validation-rmse:8.63175
# [355]#011train-rmse:20.39971#011validation-rmse:8.77705
# [356]#011train-rmse:20.39843#011validation-rmse:8.79416
# [357]#011train-rmse:20.39418#011validation-rmse:8.80054
# [358]#011train-rmse:20.39829#011validation-rmse:8.81730
# [359]#011train-rmse:20.39415#011validation-rmse:8.83854
# [360]#011train-rmse:20.43967#011validation-rmse:8.71399
# [361]#011train-rmse:20.38670#011validation-rmse:8.84051
# [362]#011train-rmse:20.38230#011validation-rmse:8.85543
# [363]#011train-rmse:20.38198#011validation-rmse:8.84731
# [364]#011train-rmse:20.41658#011validation-rmse:8.73464
# [365]#011train-rmse:20.41055#011validation-rmse:8.77862
# [366]#011train-rmse:20.45905#011validation-rmse:8.72635
# [367]#011train-rmse:20.46384#011validation-rmse:8.69609
# [368]#011train-rmse:20.45865#011validation-rmse:8.73611
# [369]#011train-rmse:20.40102#011validation-rmse:8.82868
# [370]#011train-rmse:20.43667#011validation-rmse:8.71830
# [371]#011train-rmse:20.41309#011validation-rmse:8.79486
# [372]#011train-rmse:20.41305#011validation-rmse:8.76030
# [373]#011train-rmse:20.45856#011validation-rmse:8.65339
# [374]#011train-rmse:20.41789#011validation-rmse:8.78614
# [375]#011train-rmse:20.43923#011validation-rmse:8.67207
# [376]#011train-rmse:20.41283#011validation-rmse:8.82762
# [377]#011train-rmse:20.41082#011validation-rmse:8.82433
# [378]#011train-rmse:20.39846#011validation-rmse:9.00104
# [379]#011train-rmse:20.40844#011validation-rmse:8.99055
# [380]#011train-rmse:20.44043#011validation-rmse:8.85570
# [381]#011train-rmse:20.38021#011validation-rmse:8.93305
# [382]#011train-rmse:20.39873#011validation-rmse:8.84781
# [383]#011train-rmse:20.39399#011validation-rmse:8.87418
# [384]#011train-rmse:20.36225#011validation-rmse:9.02055
# [385]#011train-rmse:20.36691#011validation-rmse:8.99540
# [386]#011train-rmse:20.33682#011validation-rmse:9.22651
# [387]#011train-rmse:20.34466#011validation-rmse:9.18362
# [388]#011train-rmse:20.33959#011validation-rmse:9.17667
# [389]#011train-rmse:20.34035#011validation-rmse:9.15522
# [390]#011train-rmse:20.35663#011validation-rmse:8.99458
# [391]#011train-rmse:20.39776#011validation-rmse:8.88694
# [392]#011train-rmse:20.38083#011validation-rmse:9.08049
# [393]#011train-rmse:20.40798#011validation-rmse:9.00575
# [394]#011train-rmse:20.39792#011validation-rmse:9.04511
# [395]#011train-rmse:20.40558#011validation-rmse:8.99242
# [396]#011train-rmse:20.37761#011validation-rmse:8.98095
# [397]#011train-rmse:20.37158#011validation-rmse:9.02576
# [398]#011train-rmse:20.37158#011validation-rmse:9.05960
# [399]#011train-rmse:20.23339#011validation-rmse:9.26954
# [400]#011train-rmse:20.23226#011validation-rmse:9.26935
# [401]#011train-rmse:20.22778#011validation-rmse:9.24690
# [402]#011train-rmse:20.22405#011validation-rmse:9.26264
# [403]#011train-rmse:20.21648#011validation-rmse:9.29474
# [404]#011train-rmse:20.21087#011validation-rmse:9.35312
# [405]#011train-rmse:20.21183#011validation-rmse:9.36483
# [406]#011train-rmse:20.23973#011validation-rmse:9.23094
# [407]#011train-rmse:20.18775#011validation-rmse:9.33423
# [408]#011train-rmse:20.18611#011validation-rmse:9.34985
# [409]#011train-rmse:20.17324#011validation-rmse:9.38621
# [410]#011train-rmse:20.20819#011validation-rmse:9.28791
# [411]#011train-rmse:20.20806#011validation-rmse:9.30584
# [412]#011train-rmse:20.20936#011validation-rmse:9.29949
# [413]#011train-rmse:20.14006#011validation-rmse:9.27546
# [414]#011train-rmse:20.13852#011validation-rmse:9.27296
# [415]#011train-rmse:20.12430#011validation-rmse:9.36233
# [416]#011train-rmse:20.10975#011validation-rmse:9.51109
# [417]#011train-rmse:20.10956#011validation-rmse:9.51694
# [418]#011train-rmse:20.12700#011validation-rmse:9.42165
# [419]#011train-rmse:20.14357#011validation-rmse:9.25446
# [420]#011train-rmse:20.14148#011validation-rmse:9.25925
# [421]#011train-rmse:20.11311#011validation-rmse:9.41729
# [422]#011train-rmse:20.14276#011validation-rmse:9.22045
# [423]#011train-rmse:20.11160#011validation-rmse:9.36484
# [424]#011train-rmse:20.11328#011validation-rmse:9.37090
# [425]#011train-rmse:20.10939#011validation-rmse:9.39284
# [426]#011train-rmse:20.10897#011validation-rmse:9.44015
# [427]#011train-rmse:20.10315#011validation-rmse:9.44548
# [428]#011train-rmse:20.13321#011validation-rmse:9.34796
# [429]#011train-rmse:20.11051#011validation-rmse:9.49106
# [430]#011train-rmse:20.14236#011validation-rmse:9.41662
# [431]#011train-rmse:20.14142#011validation-rmse:9.43327
# [432]#011train-rmse:20.15924#011validation-rmse:9.30811
# [433]#011train-rmse:20.10345#011validation-rmse:9.37824
# [434]#011train-rmse:20.10803#011validation-rmse:9.42421
# [435]#011train-rmse:20.08812#011validation-rmse:9.43838
# [436]#011train-rmse:20.14029#011validation-rmse:9.20465
# [437]#011train-rmse:20.09943#011validation-rmse:9.31251
# [438]#011train-rmse:20.08972#011validation-rmse:9.33441
# [439]#011train-rmse:20.08036#011validation-rmse:9.32587
# [440]#011train-rmse:20.10927#011validation-rmse:9.17485
# [441]#011train-rmse:20.06598#011validation-rmse:9.28846
# [442]#011train-rmse:20.05300#011validation-rmse:9.44063
# [443]#011train-rmse:20.01865#011validation-rmse:9.50928
# [444]#011train-rmse:19.99351#011validation-rmse:9.57586
# [445]#011train-rmse:19.99393#011validation-rmse:9.66109
# [446]#011train-rmse:19.98126#011validation-rmse:9.65653
# [447]#011train-rmse:19.97283#011validation-rmse:9.70915
# [448]#011train-rmse:19.97070#011validation-rmse:9.69904
# [449]#011train-rmse:19.96597#011validation-rmse:9.70253
# [450]#011train-rmse:19.96227#011validation-rmse:9.71172
# [451]#011train-rmse:19.95855#011validation-rmse:9.72681
# [452]#011train-rmse:19.95591#011validation-rmse:9.70233
# [453]#011train-rmse:19.97749#011validation-rmse:9.56998
# [454]#011train-rmse:20.01305#011validation-rmse:9.48741
# [455]#011train-rmse:19.99172#011validation-rmse:9.47956
# [456]#011train-rmse:19.96864#011validation-rmse:9.65053
# [457]#011train-rmse:19.94621#011validation-rmse:9.65567
# [458]#011train-rmse:19.94677#011validation-rmse:9.67033
# [459]#011train-rmse:19.96390#011validation-rmse:9.54482
# [460]#011train-rmse:19.92913#011validation-rmse:9.55574
# [461]#011train-rmse:19.88978#011validation-rmse:9.63035
# [462]#011train-rmse:19.88741#011validation-rmse:9.66213
# [463]#011train-rmse:19.88691#011validation-rmse:9.68999
# [464]#011train-rmse:19.87407#011validation-rmse:9.68041
# [465]#011train-rmse:19.83137#011validation-rmse:9.59937
# [466]#011train-rmse:19.82648#011validation-rmse:9.66678
# [467]#011train-rmse:19.82880#011validation-rmse:9.66372
# [468]#011train-rmse:19.85019#011validation-rmse:9.57913
# [469]#011train-rmse:19.84796#011validation-rmse:9.59458
# [470]#011train-rmse:19.84755#011validation-rmse:9.60860
# [471]#011train-rmse:19.84698#011validation-rmse:9.64854
# [472]#011train-rmse:19.84707#011validation-rmse:9.68503
# [473]#011train-rmse:19.84453#011validation-rmse:9.70478
# [474]#011train-rmse:19.84582#011validation-rmse:9.72498
# [475]#011train-rmse:19.84561#011validation-rmse:9.71044
# [476]#011train-rmse:19.84145#011validation-rmse:9.64413
# [477]#011train-rmse:19.85463#011validation-rmse:9.47205
# [478]#011train-rmse:19.84162#011validation-rmse:9.38411
# [479]#011train-rmse:19.84227#011validation-rmse:9.39772
# [480]#011train-rmse:19.87448#011validation-rmse:9.21044
# [481]#011train-rmse:19.87637#011validation-rmse:9.19793
# [482]#011train-rmse:19.89834#011validation-rmse:9.10666
# [483]#011train-rmse:19.89145#011validation-rmse:9.13584
# [484]#011train-rmse:19.89779#011validation-rmse:9.13528
# [485]#011train-rmse:19.89126#011validation-rmse:9.18218
# [486]#011train-rmse:19.91144#011validation-rmse:9.08264
# [487]#011train-rmse:19.92594#011validation-rmse:9.00011
# [488]#011train-rmse:19.92424#011validation-rmse:8.97718
# [489]#011train-rmse:19.95840#011validation-rmse:8.90597
# [490]#011train-rmse:19.90908#011validation-rmse:8.96699
# [491]#011train-rmse:19.87126#011validation-rmse:9.12820
# [492]#011train-rmse:19.82440#011validation-rmse:9.18994
# [493]#011train-rmse:19.80419#011validation-rmse:9.27014
# [494]#011train-rmse:19.81777#011validation-rmse:9.12620
# [495]#011train-rmse:19.76978#011validation-rmse:9.27351
# [496]#011train-rmse:19.77321#011validation-rmse:9.15441
# [497]#011train-rmse:19.77329#011validation-rmse:9.16680
# [498]#011train-rmse:19.77495#011validation-rmse:9.10569
# [499]#011train-rmse:19.77504#011validation-rmse:9.14549
#
# 2023-08-31 00:57:17 Uploading - Uploading generated training model
# 2023-08-31 00:57:17 Completed - Training job completed
# Training seconds: 142
# Billable seconds: 142

# %% [markdown]
# ## Host the model

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2023-08-31-00-57-43-765
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2023-08-31-00-57-43-765
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2023-08-31-00-57-43-765
# -----!

# %% [markdown]
# ## Cleanup

# %%
xgb_predictor.delete_endpoint(delete_endpoint_config=True)
# Out:
# INFO:sagemaker:Deleting endpoint configuration with name: sagemaker-xgboost-2023-08-31-00-57-43-765
# INFO:sagemaker:Deleting endpoint with name: sagemaker-xgboost-2023-08-31-00-57-43-765
